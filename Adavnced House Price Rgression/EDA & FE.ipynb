# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msn

# %%
df = pd.read_csv('housing.csv')
pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (20640, 10)

# %%
## handle missing values

# %%
msn.matrix(df)
# Out:
# <AxesSubplot:>

# %%
# we can drop those missing values rows because data set is big

# %%
df.dropna(axis=0,inplace=True)

# %%
msn.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.hist(bins=50, figsize=(10, 8))
plt.show()

# %%
plt.figure(figsize=(9,9))
sns.heatmap(df.corr(),annot=True,cmap='Wistia')
plt.show()

# %%
# we can see 'total_rooms','total_bedrooms','population','households', are highly correlated each other
#we can use a one feature insted of using thos 4 features

# %%
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']
