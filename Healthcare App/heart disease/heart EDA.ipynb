# %%
#!pip install pandas-profiling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msn
import pandas_profiling as pp
from scipy.stats import norm

# %%
df = pd.read_csv('heart.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(2)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
msn.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
pp.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.12.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-05-07 17:35:22.956643&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
categorical = ['sex', 'cp','fbs', 'restecg','exang','slope', 'ca', 'thal']

# %%
numerical = [x for x in df.columns if x not in categorical if x !='target']

# %%
for i in numerical:
    sns.distplot(df[i],fit=norm)
    plt.show()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#oldpeak is right skewed ..we have to use some data transform techniques to it

# %%
for i in categorical:
    sns.catplot(data=df, x=i,kind='count')

# %%
pd.pivot_table(data=df,index=['sex'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
pd.pivot_table(data=df,index=['cp'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='cp'>

# %%
pd.pivot_table(data=df,index=['fbs'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='fbs'>

# %%
pd.pivot_table(data=df,index=['restecg'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='restecg'>

# %%
pd.pivot_table(data=df,index=['exang'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='exang'>

# %%
pd.pivot_table(data=df,index=['slope'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='slope'>

# %%
pd.pivot_table(data=df,index=['ca'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='ca'>

# %%
pd.pivot_table(data=df,index=['thal'],values=['target'],aggfunc='mean').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='thal'>

# %%
for i in numerical:
    sns.catplot(data=df,x='target',y=i ,kind='box')
    plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,cmap='RdYlBu')
plt.show()

# %%
# no much correalted features

# %%
sns.pairplot(data=df, kind='scatter', diag_kind='hist')
