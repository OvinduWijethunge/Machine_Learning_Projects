# %%
import pandas as pd

# %%
df = pd.read_csv('hamDataCsv.csv') # use xlsx
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-1adbc6af70b5> in <module>
# ----> 1 df = pd.read_csv('hamDataCsv.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
df
# Out:
#              vid                 vdate                  comment_id  \
# 0    eXllTof3hKI  2020-10-17T10:30:05Z  UgxndISj003ucND8mF14AaABAg
# 1    eXllTof3hKI  2020-10-17T10:30:05Z  Ugy1KFcZH6NK52kVqkl4AaABAg
# 2    eXllTof3hKI  2020-10-17T10:30:05Z  UgyEF2kO0uANZMHL4lN4AaABAg
# 3    eXllTof3hKI  2020-10-17T10:30:05Z  UgzoZ_CQl5pBlWO4yBd4AaABAg
# 4    eXllTof3hKI  2020-10-17T10:30:05Z  UgxIwllikNBkbimK6Y94AaABAg
# ..           ...                   ...                         ...
# 173  eXllTof3hKI  2020-10-17T10:30:05Z  UgxhlXqP4zL9BorjbpJ4AaABAg
# 174  eXllTof3hKI  2020-10-17T10:30:05Z  UgzTp8axhb4-RxtT2Dh4AaABAg
# 175  eXllTof3hKI  2020-10-17T10:30:05Z  UgyEIBHzVmaM3UCYcuh4AaABAg
# 176  eXllTof3hKI  2020-10-17T10:30:05Z  Ugx5qcX0_lbxOfN3VB94AaABAg
# 177  eXllTof3hKI  2020-10-17T10:30:05Z  UgwB0mT0VCQmrVWwq4R4AaABAg
#
#                                                comment  \
# 0    5G දෙනකොට dialog  කාඩ් දාන එක වෙනුවට වෙන ක්‍රම...
# ...
